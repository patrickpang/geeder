# %%
response = """
- question: What is simple randomization?
  answer: Known as unrestricted randomisation, participants are allocated purely on the basis of chance (e.g. using a computer generated random number or a coin toss).
- question: What is a potential drawback of simple randomization?
  answer: Potential for unequal group sizes (not an issue with large studies).
- question: What is blocked randomization?
  answer: A technique for obtaining equal group sizes, where a block size is chosen and all permutations of assignments that meet a specified ratio are listed, then the allocation sequence is generated by randomly selecting blocks from this list.
- question: What is stratified randomization?
  answer: An approach used in smaller trials to ensure that potentially confounding variables are evenly distributed between the groups, by subdividing recruits into strata and randomizing within each stratum.
- question: What is cluster randomization?
  answer: A design where groups, rather than individuals, are randomised to receive the different interventions, requiring consideration of sample size at the design stage.
- question: What is matched pair randomization?
  answer: Individuals or groups are first matched according to baseline data, then the intervention is randomly allocated to one member of the pair, with the other member receiving the control.
- question: What is stepped wedge randomization?
  answer: The population is divided into groups and the intervention is progressively introduced, in random order, across the groups until every group is receiving it, often used when other methods would be unfeasible due to a widespread belief that the intervention will be beneficial.
"""

# %%
# %pip install PyYAML==6.0.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 696.9/696.9 kB 9.4 MB/s eta 0:00:00:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yaml
yaml.safe_load(response)
# Out:
# [{'question': 'What is simple randomization?',
#   'answer': 'Known as unrestricted randomisation, participants are allocated purely on the basis of chance (e.g. using a computer generated random number or a coin toss).'},
#  {'question': 'What is a potential drawback of simple randomization?',
#   'answer': 'Potential for unequal group sizes (not an issue with large studies).'},
#  {'question': 'What is blocked randomization?',
#   'answer': 'A technique for obtaining equal group sizes, where a block size is chosen and all permutations of assignments that meet a specified ratio are listed, then the allocation sequence is generated by randomly selecting blocks from this list.'},
#  {'question': 'What is stratified randomization?',
#   'answer': 'An approach used in smaller trials to ensure that potentially confounding variables are evenly distributed between the groups, by subdividing recruits into strata and randomizing within each stratum.'},
# ...
